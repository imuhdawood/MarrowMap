# %%
import spatialdata as sd

# %%
obj = sd.read_zarr("<insert path for zarr object>")

# %%
adata = obj.tables["table"]

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 461772 × 480
#     obs: 'cell_id', 'transcript_counts', 'control_probe_counts', 'control_codeword_counts', 'unassigned_codeword_counts', 'deprecated_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'region', 'z_level', 'nucleus_count', 'cell_labels'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatialdata_attrs'
#     obsm: 'spatial'

# %%
import anndata as ad

#save the anndata

adata.write_h5ad("<insert desired path to save anndata object to>")
