# %%
import spatialdata as sd

# %%
obj = sd.read_zarr("/well/rittscher/users/qdv200/MPN/xenium/muskaan_project/033691_R2.zarr")
# Out:
# /well/rittscher/users/qdv200/conda/skylake/envs/xenium_env2/lib/python3.10/site-packages/anndata/_core/aligned_df.py:67: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %%
adata = obj.tables["table"]

# %%
adata.obs
# Out:
#            cell_id  transcript_counts  control_probe_counts  \
# 0       aaaabjip-1                 83                     0
# 1       aaaaemgg-1                 65                     0
# 2       aaaamenh-1                135                     0
# 3       aaaaminb-1                119                     0
# 4       aaaanfim-1                151                     0
# ...            ...                ...                   ...
# 461767  oioigbpg-1                 34                     0
# 461768  oioigdgj-1                 42                     0
# 461769  oioikpkh-1                 37                     0
# 461770  oioillfb-1                 19                     0
# 461771  oiojajep-1                 13                     0
#
#         control_codeword_counts  unassigned_codeword_counts  \
# 0                             0                           0
# 1                             0                           0
# 2                             0                           0
# ...

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 461772 × 480
#     obs: 'cell_id', 'transcript_counts', 'control_probe_counts', 'control_codeword_counts', 'unassigned_codeword_counts', 'deprecated_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'region', 'z_level', 'nucleus_count', 'cell_labels'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatialdata_attrs'
#     obsm: 'spatial'

# %%
import anndata as ad

#save the anndata

adata.write_h5ad("/well/rittscher/users/qdv200/MPN/xenium/muskaan_project/033691_R2.h5ad")
